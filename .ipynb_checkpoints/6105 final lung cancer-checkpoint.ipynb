# %% [markdown]
# # What contributes to lung cancer deaths and what can we do?
# We aim to address the critical issue of lung cancer through a comprehensive data-driven approach. By leveraging predictive analytics, geospatial data, and historical trends, our project seeks to uncover underlying patterns and risk factors associated with lung cancer. Through our analysis, we aspire to contribute to effective strategies that can mitigate the impact of this devastating disease, promoting longer and healthier lives.

# %% [markdown]
# ![Literate_Programming](p4.jpg)

# %%
import pandas as pd
import os

base_file_path = os.path.join("data_csv/", "lung cancer death rates by country by year.csv")
base_df = pd.read_csv(base_file_path)

other_files = [f for f in os.listdir("data_csv/") if f.endswith('.csv') and f != "lung cancer death rates by country by year.csv"]

merged_df = base_df.copy()
for file in other_files:
    file_path = os.path.join("data_csv/", file)
    df = pd.read_csv(file_path)
    df = df.drop(columns=['Entity'], errors='ignore')

    merged_df = merged_df.merge(df, on=['Code', 'Year'], how='left')

merged_df.to_csv('merged_data.csv', index=False)

# %%
merged_df.shape
# Out:
# (2116, 13)

# %%
merged_df.head(10)
# Out:
#     Entity Code  Year  Number  \
# 0  Albania  ALB  2003     651
# 1  Albania  ALB  2004     605
# 2  Albania  ALB  2000     593
# 3  Albania  ALB  2006     567
# 4  Albania  ALB  2002     597
# 5  Albania  ALB  2001     510
# 6  Albania  ALB  2005     543
# 7  Albania  ALB  2007     515
# 8  Albania  ALB  2008     617
# 9  Albania  ALB  2010     352
#
#    Percentage of cause-specific deaths out of total deaths  \
# 0                                           3.623713
# 1                                           3.408835
# 2                                           3.613430
# 3                                           3.348096
# 4                                           3.674298
# 5                                           3.367893
# 6                                           3.115855
# 7                                           3.544879
# 8                                           3.822090
# 9                                           2.899745
#
#    Age-standardized death rate per 100 000 standard population  \
# 0                                          22.266104
# 1                                          19.885788
# 2                                          23.079543
# 3                                          17.373549
# 4                                          21.000429
# 5                                          18.061525
# 6                                          17.119361
# 7                                          15.267667
# 8                                          17.813910
# 9                                           9.558446
#
#    Death rate per 100 000 population  \
# 0                          20.981293
# 1                          19.345990
# 2                          19.043031
# 3                          18.947046
# 4                          19.357035
# 5                          16.616302
# 6                          18.030941
# 7                          17.339945
# 8                          20.934272
# 9                          12.083642
#
#    Proportion of population with primary reliance on clean fuels and technologies for cooking (%) - Residence area type: Total  \
# 0                                               46.5
# 1                                               49.2
# 2                                               38.7
# 3                                               54.8
# 4                                               43.8
# 5                                               41.0
# 6                                               52.0
# 7                                               57.8
# 8                                               60.7
# 9                                               65.8
#
#    Life expectancy - Type: period - Sex: both - Age: 0  \
# 0                                            76.1421
# 1                                            76.3761
# 2                                            75.4043
# 3                                            76.8162
# 4                                            75.8899
# 5                                            75.6388
# 6                                            76.6208
# 7                                            77.5491
# 8                                            77.6529
# 9                                            77.9359
#
#    PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          24.302870
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                          22.169489
# 7                                                NaN
# 8                                                NaN
# 9                                          21.631449
#
#    GDP per capita, PPP (constant 2017 international $)  \
# 0                                          7154.0303
# 1                                          7580.1650
# 2                                          5892.6110
# 3                                          8568.5920
# 4                                          6753.9140
# 5                                          6441.4720
# 6                                          8040.1206
# 7                                          9150.1610
# 8                                          9912.1970
# 9                                         10749.5190
#
#    public_health_expenditure_pc_gdp  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                             2.442
#
#    Prevalence of current tobacco use (% of adults)
# 0                                              NaN
# 1                                              NaN
# 2                                             35.0
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                             31.3
# 7                                              NaN
# 8                                              NaN
# 9                                             28.0

# %%
merged_df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Number',
#        'Percentage of cause-specific deaths out of total deaths',
#        'Age-standardized death rate per 100 000 standard population',
#        'Death rate per 100 000 population',
#        'Proportion of population with primary reliance on clean fuels and technologies for cooking (%) - Residence area type: Total',
#        'Life expectancy - Type: period - Sex: both - Age: 0',
#        'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
#        'GDP per capita, PPP (constant 2017 international $)',
#        'public_health_expenditure_pc_gdp',
#        'Prevalence of current tobacco use (% of adults)'],
#       dtype='object')

# %%
unique_countries = merged_df['Entity'].nunique()
unique_countries
# Out:
# 118

# %% [markdown]
# **There are so many countries and they vary a lot. Which countries should we focus? Let's see in most recent year which countries have the highest death rate caused by lung cancer?**

# %%
countries_per_year = merged_df.groupby('Year')['Entity'].nunique().sort_index(ascending=False)
countries_per_year
# Out:
# Year
# 2022     15
# 2021     52
# 2020     67
# 2019     84
# 2018     85
# 2017     90
# 2016     99
# 2015     97
# 2014    102
# 2013    100
# 2012    101
# 2011    103
# 2010    105
# 2009    106
# 2008    102
# 2007    102
# 2006    100
# 2005    100
# 2004    101
# 2003    102
# 2002    102
# 2001    103
# 2000     98
# Name: Entity, dtype: int64

# %% [markdown]
# The most recent data we have is for 2022, but it seems year 2021 has more data, let's go with 2021.

# %%
data_2021 = merged_df[merged_df['Year'] == 2021].sort_values(
    by='Age-standardized death rate per 100 000 standard population', 
    ascending=False
)
data_2021.head(20)
# Out:
#                         Entity Code  Year  Number  \
# 2110                   Hungary  HUN  2021    7867
# 1964                    Serbia  SRB  2021    4615
# 2066                   Croatia  HRV  2021    2814
# 2096                    Poland  POL  2021   20866
# 1507                   Armenia  ARM  2021    1181
# 2090               Netherlands  NLD  2021   10095
# 2056                      Cuba  CUB  2021    5341
# 2061                   Denmark  DNK  2021    3381
# 2047    Bosnia and Herzegovina  BIH  2021    1665
# 2054                    Canada  CAN  2021   19578
# 1790                    Latvia  LVA  2021     931
# 2046                  Bulgaria  BGR  2021    3244
# 1818           North Macedonia  MKD  2021     781
# 1635                     Spain  ESP  2021   22438
# 1519                   Austria  AUT  2021    4073
# 2102  United States of America  USA  2021  134592
# 1592                   Czechia  CZE  2021    4898
# 1641                   Estonia  EST  2021     603
# 1825                  Mongolia  MNG  2021     451
# 2073                   Iceland  ISL  2021     128
#
#       Percentage of cause-specific deaths out of total deaths  \
# 2110                                           5.055230
# 1964                                           3.377933
# 2066                                           4.487179
# 2073                                                NaN
#
#       GDP per capita, PPP (constant 2017 international $)  \
# 2110                                          33583.785
# 1964                                          19860.310
# 2066                                          32060.504
# 2096                                          34944.040
# 1507                                          14206.545
# 2090                                          57334.703
# 2056                                                NaN
# 2061                                          58802.960
# 2047                                          15893.156
# 2054                                          48356.332
# 1790                                          31833.842
# 2046                                          24386.180
# 1818                                          16708.598
# 1635                                          38319.290
# 1519                                          53817.305
# 2102                                          63635.824
# 1592                                          40744.457
# 1641                                          38717.695
# 1825                                          11668.431
# 2073                                          53135.953
#
#       public_health_expenditure_pc_gdp  \
# 2110                             5.303
# 1964                               NaN
# 2066                               NaN
# 2096                             4.785
# 1507                               NaN
# 2090                               NaN
# 2056                               NaN
# 2061                             9.264
# 2047                               NaN
# 2054                             8.695
# 1790                               NaN
# 2046                               NaN
# 1818                               NaN
# 1635                               NaN
# 1519                             9.555
# 2102                               NaN
# 1592                               NaN
# 1641                             5.860
# 1825                               NaN
# 2073                             8.060
#
#       Prevalence of current tobacco use (% of adults)
# 2110                                              NaN
# 1964                                              NaN
# 2066                                              NaN
# 2096                                              NaN
# 1507                                              NaN
# 2090                                              NaN
# 2056                                              NaN
# 2061                                              NaN
# 2047                                              NaN
# 2054                                              NaN
# 1790                                              NaN
# 2046                                              NaN
# 1818                                              NaN
# 1635                                              NaN
# 1519                                              NaN
# 2102                                              NaN
# 1592                                              NaN
# 1641                                              NaN
# 1825                                              NaN
# 2073                                              NaN

# %% [markdown]
# 因为不是所有的参数在每一年都有数据，所以这里看2021年的有些column是空的...
#
# 或许可以pick几个国家比如Hungary，Serbia，Cuba，USA，Iceland...用他们各自全部的数据分别画pair plot看是否有相关性?
#
# e.g.  USA:
#  - Age-standardized death rate vs PM2.5 air pollution
#  - Age-standardized death rate vs Prevalence of current tobacco use
#  - Age-standardized death rate vs public_health_expenditure
#  - ...

# %%
# 直接看表的话2000,2005,2010,2015,2018,2019年的数据比较完整

# %% [markdown]
# Now lets pick up some contries to have pari plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('merged_data.csv')

usa_data = data[data['Entity'] == 'United States of America']
hungary_data = data[data['Entity'] == 'Hungary']

usa_data = usa_data.dropna(subset=['Age-standardized death rate per 100 000 standard population', 'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)'])
hungary_data = hungary_data.dropna(subset=['Age-standardized death rate per 100 000 standard population', 
                                           'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)'])

# conbine them
combined_data = pd.concat([usa_data, hungary_data])

plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)',
    y='Age-standardized death rate per 100 000 standard population',
    data=combined_data,
    hue='Entity', 
    palette={'United States of America': 'blue', 'Hungary': 'red'}, 
    s=100, alpha=0.6, edgecolor='none'
)

plt.title('Correlation between Age-Standardized Death Rate and PM2.5 Exposure in USA')
plt.xlabel('PM2.5 Air Pollution (micrograms per cubic meter)')
plt.ylabel('Age-Standardized Death Rate per 100,000 Population')
plt.grid(True) 

plt.show()
